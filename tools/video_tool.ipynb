# %%
import moviepy.editor as mp
from moviepy.video.fx.all import resize
import PIL.Image as Image

# %%
#"C:\\Users\\Marcio\\OneDrive\Área de Trabalho\\WorldWideCourses\\afiliados\\Ejaculação\\Treino CONTROLE 2 0： Como ELIMINAR A CAUSA da ejaculação precoce.mp4"

clip = mp.VideoFileClip("C:\\Users\\Marcio\\OneDrive\Área de Trabalho\\WorldWideCourses\\afiliados\\Ejaculação\\Treino.mp4")
print(f"Width: {clip.w}, Height: {clip.h}")
clip_resized = clip.resize(height=360) # make the height 360px ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
clip_resized.write_videofile("C:\\Users\\Marcio\\OneDrive\Área de Trabalho\\WorldWideCourses\\afiliados\\Ejaculação\\controle_resized.mp4")
print(f"Width: {clip_resized.w}, Height: {clip_resized.h}")
# Out:
# Width: 1920, Height: 1080
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       3 clip = mp.VideoFileClip("C:\\Users\\Marcio\\OneDrive\Área de Trabalho\\WorldWideCourses\\afiliados\\Ejaculação\\Treino.mp4")
#       4 print(f"Width: {clip.w}, Height: {clip.h}")
# ----> 5 clip_resized = clip.resize(height=360) # make the height 360px ( According to moviePy documenation The width is then computed so that the width/height ratio is conserved.)
#       6 clip_resized.write_videofile("C:\\Users\\Marcio\\OneDrive\Área de Trabalho\\WorldWideCourses\\afiliados\\Ejaculação\\controle_resized.mp4")
#       7 print(f"Width: {clip_resized.w}, Height: {clip_resized.h}")
#
# File c:\Python312\Lib\site-packages\moviepy\video\fx\resize.py:152, in resize(clip, newsize, height, width, apply_to_mask)
#     149 else:
# ...
